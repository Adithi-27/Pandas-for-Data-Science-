# %% [markdown]
# 1. Working with NaN
# 2. Handling NaN Values

# %%
import numpy as np
import pandas as pd

# %%
data = np.random.rand(10, 3)
for col in range(data.shape[1]):
    null_indices = np.random.choice(10, 3, replace=False)
    data[null_indices, col] = np.nan
df = pd.DataFrame(data, columns=['Column_1', 'Column_2', 'Column_3'])

# %%
df.head(6)
# Out:
#    Column_1  Column_2  Column_3
# 0  0.196527  0.445781  0.737448
# 1       NaN  0.761807  0.193893
# 2  0.277863       NaN       NaN
# 3  0.263880  0.516244  0.060291
# 4  0.661158       NaN       NaN
# 5  0.782812  0.948562  0.634184

# %%
#checking with pd.isna()
pd.isna(df['Column_1'])
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# 9     True
# Name: Column_1, dtype: bool

# %%
pd.isna(df)
# Out:
#    Column_1  Column_2  Column_3
# 0     False     False     False
# 1      True     False     False
# 2     False      True      True
# 3     False     False     False
# 4     False      True      True
# 5     False     False     False
# 6      True      True      True
# 7     False     False     False
# 8     False     False     False
# 9      True     False     False

# %%
#checking with pd.notna()
pd.notna(df['Column_1'])
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# 5     True
# 6    False
# 7     True
# 8     True
# 9    False
# Name: Column_1, dtype: bool

# %%
pd.notna(df)
# Out:
#    Column_1  Column_2  Column_3
# 0      True      True      True
# 1     False      True      True
# 2      True     False     False
# 3      True      True      True
# 4      True     False     False
# 5      True      True      True
# 6     False     False     False
# 7      True      True      True
# 8      True      True      True
# 9     False      True      True

# %%
#checking with isnull().sum()
df.isnull()
# Out:
#    Column_1  Column_2  Column_3
# 0     False     False     False
# 1      True     False     False
# 2     False      True      True
# 3     False     False     False
# 4     False      True      True
# 5     False     False     False
# 6      True      True      True
# 7     False     False     False
# 8     False     False     False
# 9      True     False     False

# %%
df.isnull().sum()
# Out:
# Column_1    3
# Column_2    3
# Column_3    3
# dtype: int64

# %%
#checking with notnull().sum()
df.notnull().sum()
# Out:
# Column_1    7
# Column_2    7
# Column_3    7
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Column_1  7 non-null      float64
#  1   Column_2  7 non-null      float64
#  2   Column_3  7 non-null      float64
# dtypes: float64(3)
# memory usage: 368.0 bytes

# %%
df
# Out:
#    Column_1  Column_2  Column_3
# 0  0.196527  0.445781  0.737448
# 1       NaN  0.761807  0.193893
# 2  0.277863       NaN       NaN
# 3  0.263880  0.516244  0.060291
# 4  0.661158       NaN       NaN
# 5  0.782812  0.948562  0.634184
# 6       NaN       NaN       NaN
# 7  0.818899  0.214606  0.258876
# 8  0.186715  0.735984  0.423808
# 9       NaN  0.201626  0.691096

# %% [markdown]
# Handling NaN Values

# %%
df
# Out:
#    Column_1  Column_2  Column_3
# 0  0.196527  0.445781  0.737448
# 1       NaN  0.761807  0.193893
# 2  0.277863       NaN       NaN
# 3  0.263880  0.516244  0.060291
# 4  0.661158       NaN       NaN
# 5  0.782812  0.948562  0.634184
# 6       NaN       NaN       NaN
# 7  0.818899  0.214606  0.258876
# 8  0.186715  0.735984  0.423808
# 9       NaN  0.201626  0.691096

# %%
df.isnull().sum()
# Out:
# Column_1    3
# Column_2    3
# Column_3    3
# dtype: int64

# %%
df1 = df.copy()

# %%
df1.fillna(0, inplace=True)

# %%
df1.isnull().sum()
# Out:
# Column_1    0
# Column_2    0
# Column_3    0
# dtype: int64

# %%
df1.head()
# Out:
#    Column_1  Column_2  Column_3
# 0  0.196527  0.445781  0.737448
# 1  0.000000  0.761807  0.193893
# 2  0.277863  0.000000  0.000000
# 3  0.263880  0.516244  0.060291
# 4  0.661158  0.000000  0.000000

# %%
df
# Out:
#    Column_1  Column_2  Column_3
# 0  0.196527  0.445781  0.737448
# 1       NaN  0.761807  0.193893
# 2  0.277863       NaN       NaN
# 3  0.263880  0.516244  0.060291
# 4  0.661158       NaN       NaN
# 5  0.782812  0.948562  0.634184
# 6       NaN       NaN       NaN
# 7  0.818899  0.214606  0.258876
# 8  0.186715  0.735984  0.423808
# 9       NaN  0.201626  0.691096

# %%
df.fillna(
{
    'Column_1': 0,
    'Column_2' : 1,
    'Column_3': 2
})
# Out:
#    Column_1  Column_2  Column_3
# 0  0.196527  0.445781  0.737448
# 1  0.000000  0.761807  0.193893
# 2  0.277863  1.000000  2.000000
# 3  0.263880  0.516244  0.060291
# 4  0.661158  1.000000  2.000000
# 5  0.782812  0.948562  0.634184
# 6  0.000000  1.000000  2.000000
# 7  0.818899  0.214606  0.258876
# 8  0.186715  0.735984  0.423808
# 9  0.000000  0.201626  0.691096

# %%
df
# Out:
#    Column_1  Column_2  Column_3
# 0  0.196527  0.445781  0.737448
# 1       NaN  0.761807  0.193893
# 2  0.277863       NaN       NaN
# 3  0.263880  0.516244  0.060291
# 4  0.661158       NaN       NaN
# 5  0.782812  0.948562  0.634184
# 6       NaN       NaN       NaN
# 7  0.818899  0.214606  0.258876
# 8  0.186715  0.735984  0.423808
# 9       NaN  0.201626  0.691096

# %%
df.dropna(how='any')
# Out:
#    Column_1  Column_2  Column_3
# 0  0.196527  0.445781  0.737448
# 3  0.263880  0.516244  0.060291
# 5  0.782812  0.948562  0.634184
# 7  0.818899  0.214606  0.258876
# 8  0.186715  0.735984  0.423808

# %%
df.dropna(how='all')
# Out:
#    Column_1  Column_2  Column_3
# 0  0.196527  0.445781  0.737448
# 1       NaN  0.761807  0.193893
# 2  0.277863       NaN       NaN
# 3  0.263880  0.516244  0.060291
# 4  0.661158       NaN       NaN
# 5  0.782812  0.948562  0.634184
# 7  0.818899  0.214606  0.258876
# 8  0.186715  0.735984  0.423808
# 9       NaN  0.201626  0.691096

# %%
df.dropna(thresh=2)
# Out:
#    Column_1  Column_2  Column_3
# 0  0.196527  0.445781  0.737448
# 1       NaN  0.761807  0.193893
# 3  0.263880  0.516244  0.060291
# 5  0.782812  0.948562  0.634184
# 7  0.818899  0.214606  0.258876
# 8  0.186715  0.735984  0.423808
# 9       NaN  0.201626  0.691096

# %%
df.dropna(thresh=3)
# Out:
#    Column_1  Column_2  Column_3
# 0  0.196527  0.445781  0.737448
# 3  0.263880  0.516244  0.060291
# 5  0.782812  0.948562  0.634184
# 7  0.818899  0.214606  0.258876
# 8  0.186715  0.735984  0.423808

# %%
df.dropna(thresh=4)
# Out:
# Empty DataFrame
# Columns: [Column_1, Column_2, Column_3]
# Index: []

# %%
df.fillna(
{
    'Column_1': 'aiquest.org',
    'Column_2' : 'study mart',
    'Column_3': 'data science'
})
# Out:
#       Column_1    Column_2      Column_3
# 0     0.196527    0.445781      0.737448
# 1  aiquest.org    0.761807      0.193893
# 2     0.277863  study mart  data science
# 3      0.26388    0.516244      0.060291
# 4     0.661158  study mart  data science
# 5     0.782812    0.948562      0.634184
# 6  aiquest.org  study mart  data science
# 7     0.818899    0.214606      0.258876
# 8     0.186715    0.735984      0.423808
# 9  aiquest.org    0.201626      0.691096

# %% [markdown]
# Filling NaN (missing) values with central tendency

# %%
df.fillna(df.mean())
# Out:
#    Column_1  Column_2  Column_3
# 0  0.196527  0.445781  0.737448
# 1  0.455408  0.761807  0.193893
# 2  0.277863  0.546373  0.428514
# 3  0.263880  0.516244  0.060291
# 4  0.661158  0.546373  0.428514
# 5  0.782812  0.948562  0.634184
# 6  0.455408  0.546373  0.428514
# 7  0.818899  0.214606  0.258876
# 8  0.186715  0.735984  0.423808
# 9  0.455408  0.201626  0.691096

# %%
df
# Out:
#    Column_1  Column_2  Column_3
# 0  0.196527  0.445781  0.737448
# 1       NaN  0.761807  0.193893
# 2  0.277863       NaN       NaN
# 3  0.263880  0.516244  0.060291
# 4  0.661158       NaN       NaN
# 5  0.782812  0.948562  0.634184
# 6       NaN       NaN       NaN
# 7  0.818899  0.214606  0.258876
# 8  0.186715  0.735984  0.423808
# 9       NaN  0.201626  0.691096

# %%
df.mean()
# Out:
# Column_1    0.455408
# Column_2    0.546373
# Column_3    0.428514
# dtype: float64

# %%
df.fillna(df.median()) # for outlier
# Out:
#    Column_1  Column_2  Column_3
# 0  0.196527  0.445781  0.737448
# 1  0.277863  0.761807  0.193893
# 2  0.277863  0.516244  0.423808
# 3  0.263880  0.516244  0.060291
# 4  0.661158  0.516244  0.423808
# 5  0.782812  0.948562  0.634184
# 6  0.277863  0.516244  0.423808
# 7  0.818899  0.214606  0.258876
# 8  0.186715  0.735984  0.423808
# 9  0.277863  0.201626  0.691096

# %%
df
# Out:
#    Column_1  Column_2  Column_3
# 0  0.196527  0.445781  0.737448
# 1       NaN  0.761807  0.193893
# 2  0.277863       NaN       NaN
# 3  0.263880  0.516244  0.060291
# 4  0.661158       NaN       NaN
# 5  0.782812  0.948562  0.634184
# 6       NaN       NaN       NaN
# 7  0.818899  0.214606  0.258876
# 8  0.186715  0.735984  0.423808
# 9       NaN  0.201626  0.691096

# %%
df.Column_1.mode().iloc[0]
# Out:
# 0.18671547451781
